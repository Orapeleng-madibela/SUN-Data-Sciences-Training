# %%
#import libraries
import pandas as pd
import seaborn as sns
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# ## Conditional Statements

# %% [markdown]
# **if statement**

# %%
#Tossing a coin.
coin = np.random.choice(['heads','tails'])

# %%
#what is the value of coin
coin
# Out:
# np.str_('heads')

# %%
#If the coin lands on heads, Remo wins.
if coin == 'heads':
  print('Remo wins')
# Out:
# Remo wins

# %% [markdown]
# **if-else statement**

# %%
#If the coin lands on heads, Remo wins. If the coin lands on tail, Kele wins.
coin = 'tails'

if coin == 'heads':
  print('Remo wins')
else:
  print('Kele wins')
# Out:
# Kele wins

# %%
#let's put the toss and the conditional statement together
coin = np.random.choice(['heads','tails'])

if coin == 'heads':
  print('Remo wins')
else:
  print('Kele wins')
# Out:
# Remo wins

# %% [markdown]
# **if-elif-else statement**

# %%
#generate a random number between 1 and 6 (inclusive). It's like rolling a dice.
dice_throw = np.random.randint(1,7)

# %%
#using a conditional statement where if the random number is less than or equal to 3, Remo wins. If the number is equal to 4 or 5, Kele wins.
#If it is equal to 6, the Onka wins.

if dice_throw <= 3:
  print('Remo wins')
elif dice_throw == 4 or dice_throw == 5:
  print('Kele wins')
elif dice_throw == 6:
  print('Onka wins')
# Out:
# Remo wins

# %%
#put it all together
dice_throw = np.random.randint(1,7)

if dice_throw <= 3:
  print('Remo wins')
elif dice_throw == 4 or dice_throw == 5:
  print('Kele wins')
elif dice_throw == 6:
  print('Onka wins')
# Out:
# Kele wins

# %% [markdown]
# **Replace the last elif with else as a catch all condition, that must be run if no former conditions are fulfilled.**

# %%
#Let's put it all together
dice_throw = np.random.randint(1,7)

if dice_throw <= 3:
  print('Remo wins')
elif dice_throw == 4 or dice_throw == 5:
  print('Kele wins')
else:
  print('Onka wins')
# Out:
# Kele wins

# %% [markdown]
# **Nested if statements**

# %%
#Roll a dice. If the number is less than 3, Remo wins.
#If greater than 3, then a coin is tossed and if the coin is heads, then Kele wins, else Onka wins.

dice_throw = np.random.randint(1,7)

if dice_throw < 3:
  print('Remo wins')
else:
  coin = np.random.choice(['heads','tails'])
  if coin == 'heads':
    print('Kele wins')
  else:
    print('Onka wins')
# Out:
# Kele wins

# %% [markdown]
# ## Iterations

# %% [markdown]
# Iterations allows us to repeat code multiple times.

# %%
#Remember np.arange(1,7)
np.arange(1,7)
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
#write a for statement
for i in np.arange(1,7):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
#what if we use np.arange(5,9)
for i in np.arange(5,9):
  print(i)
# Out:
# 5
# 6
# 7
# 8

# %%
#if we put strings in the array
for i in ['remo','kele','onka','kea','otshe']:
  print(i)
# Out:
# remo
# kele
# onka
# kea
# otshe

# %%
#Let's generate multiple throws of dice
#throws a dice 15 times
np.random.randint(1,7,15)
# Out:
# array([4, 6, 1, 4, 2, 3, 4, 5, 5, 2, 3, 2, 3, 3, 1], dtype=int32)

# %%
#Now use these numbers to determine whether Remo, Kele or Onka won based on the conditions given earlier

throws = np.random.randint(1,7,15)
for i in throws:
  if i <= 3:
    print('Remo wins')
  elif i == 4 or i == 5:
    print('Kele wins')
  else:
    print('Onka wins')
# Out:
# Remo wins
# Remo wins
# Kele wins
# Remo wins
# Kele wins
# Remo wins
# Kele wins
# Remo wins
# Remo wins
# Remo wins
# Remo wins
# Remo wins
# Kele wins
# Remo wins
# Remo wins

# %%
#Let's create an array with the results


results = []
throws = np.random.randint(1,7,10)
for temp in throws:
  if temp <= 3:
    ans = 'Remo'
  elif temp == 4 or temp == 5:
    ans = 'Kele'
  else:
    ans = 'Onka'

  results.append(ans)


print(results)
# Out:
# ['Kele', 'Onka', 'Kele', 'Remo', 'Remo', 'Kele', 'Remo', 'Kele', 'Remo', 'Onka']

# %%
#Let's make this neater

# %%
#how many times did Kele win
results.count('Kele')
# Out:
# 4

# %%
#how many times did Remo win
#how many times did Onka win
[results.count('Remo'),results.count('Onka')]
# Out:
# [4, 2]

# %% [markdown]
# **While loop basics**

# %%
#i = 1. Run a loop such that while i is less than 5, print i

i=1

while i < 5:
  print(i)
  i+=1
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# **Break statement**

# %%
#Let's see how we can exit a for loop
#Let's look at someone to decide whether they can vote or not.
#Voting age is 18.

age = 1

while age < 21:
  if age < 18:
    print('You cannot vote')
  else:
    print('You can vote')

  age = age + 1

  if age == 20:
    break
# Out:
# You cannot vote
# You cannot vote
# You cannot vote
# You cannot vote
# You cannot vote
# You cannot vote
# You cannot vote
# You cannot vote
# You cannot vote
# You cannot vote
# You cannot vote
# You cannot vote
# You cannot vote
# You cannot vote
# You cannot vote
# You cannot vote
# You cannot vote
# You can vote
# You can vote

# %% [markdown]
# ## Exercise

# %% [markdown]
# Suppose you toss a coin and throw a dice. If the coin lands on heads and the dice is less than or equal to 3, Kanshu wins. If the coin lands on heads and dice is greater than 3, Sunday win. If the coin lands on tails and the dice is equal to 1, Sunday wins. If the coin lands on tails and the dice is greater than or equal to 2, Marike win.
#
# Run the above simulation 100 times and count the number of times that each person wins.

# %%
results = []

for i in np.arange(100):
  coin = np.random.choice(['heads','tails'])
  dice = np.random.randint(1,7)
  if coin == 'heads':
    if dice <= 3:
      ans = 'Kanshu'
    else:
      ans = 'Sunday'
  else:
    if dice == 1:
      ans = 'Sunday'
    else:
      ans = 'Marike'

  results.append(ans)

[results.count('Marike'),results.count('Sunday'),results.count('Kanshu')]
